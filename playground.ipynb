# %%
import random
from collections import defaultdict
from typing import Callable

import numpy as np
from tqdm import tqdm

from interface import Producer, Recoverer

def test(
    producer_constructor: Callable[[int, int, int], Producer],
    recoverer_constructor: Callable[[int, int], Recoverer],
    N: int,
    D: int,
    passes: int = 100,
    sample_burst_size: Callable[[], int] = lambda: random.randint(1, 5),
    sample_data_size: Callable[[], int] = lambda: random.randint(3, 30),
    iters_bound: int = 10000,
):
    time_to_recover_distribution = defaultdict(lambda: 0)

    init_pat = 3
    patience = init_pat
    mismatch = 0

    for _ in tqdm(range(passes)):
        # Make random binary data matrix
        data = random.randint(0, D - 1)
        recovered = None

        # Initialize producer and recoverer
        producer = producer_constructor(data, N, D)
        recoverer = recoverer_constructor(N, D)
        time_to_recover = 0

        for _ in range(iters_bound):
            # Skip samples
            burst_size = sample_burst_size()
            time_to_recover += burst_size
            for _ in range(burst_size):
                producer.generate()

            # Use samples
            for _ in range(sample_data_size()):
                sample = producer.generate()
                assert sample.shape == (N,) and sample.dtype == np.uint8 and np.all((sample <= 1)), "Generated sample has invalid format"
                time_to_recover += 1
                recovered = recoverer.feed(sample)
                if recovered is not None:
                    break

            if recovered is not None:
                break

            recoverer.feed(None)  # Indicate end of continuity

        if recovered is None:
            if patience > 0:
                print(f"Failed to recover {data} within iteration bound")
            patience -= 1
            passes -= 1
            continue

        # Check correctness
        # assert np.array_equal(recovered, data), f"Expected {data}, got {recovered}"
        if not np.array_equal(recovered, data):
            if patience > 0:
                print(f"Data mismatch: expected {data}, got {recovered}")
                patience -= 1
            mismatch += 1
            passes -= 1
            continue

        time_to_recover_distribution[time_to_recover] += 1
    
    print(f"{init_pat - patience} failures.")
    if mismatch > 0:
        print(f"{mismatch} MISMATCHES!!!")
    return {k: v / passes for k, v in time_to_recover_distribution.items()}

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.io as pio
from IPython.display import HTML, display
import math

def visualize_distribution(D: int, distribution: dict):
    # Handle empty or invalid distributions early to avoid NaN -> int conversions
    if not distribution:
        print("Empty distribution — nothing to plot.")
        return

    # Convert the result (dict: time -> probability) into a sorted DataFrame
    # result is expected to be a dict mapping int -> float (probability)
    df = pd.DataFrame(list(distribution.items()), columns=["time_to_recover", "prob"]) 
    df = df.sort_values("time_to_recover").reset_index(drop=True)

    if df.empty:
        print("Distribution DataFrame is empty — nothing to plot.")
        return

    # min/max can be NaN if df is empty or has invalid values; guard against that
    raw_min = df["time_to_recover"].min()
    raw_max = df["time_to_recover"].max()
    if pd.isna(raw_min) or pd.isna(raw_max):
        print("Distribution has invalid time bounds — nothing to plot.")
        return
    min_t = int(raw_min)
    max_t = int(raw_max)

    # Reindex to a full integer range so smoothing is continuous across missing bins
    full_idx = pd.Series(range(min_t, max_t + 1), name="time_to_recover")
    df_full = pd.DataFrame({"time_to_recover": full_idx})
    df_full = df_full.merge(df, on="time_to_recover", how="left").fillna(0)

    # Smoothing: Gaussian kernel convolution implemented with NumPy
    # Choose sigma adaptively relative to range length (tune divisor to change smoothness)
    range_len = max_t - min_t + 1
    sigma = max(1.0, range_len / 100.0)  # smaller divisor -> stronger smoothing
    radius = max(1, int(3 * sigma))
    _x = np.arange(-radius, radius + 1)
    _kernel = np.exp(-0.5 * (_x / sigma) ** 2)
    _kernel = _kernel / _kernel.sum()

    prob_arr = df_full["prob"].to_numpy()
    smoothed = np.convolve(prob_arr, _kernel, mode="same")
    df_full["smoothed"] = smoothed

    # Adaptive downsampling / binning for plotting to avoid extremely large HTML payloads
    # Keep at most max_plot_points points in the exported plot
    max_plot_points = 500
    if range_len > max_plot_points:
        bin_size = int(math.ceil(range_len / max_plot_points))
        # Create bins that partition the integer range; right=False ensures contiguous ranges
        bins = list(range(min_t, max_t + bin_size, bin_size))
        df_full["bin"] = pd.cut(df_full["time_to_recover"], bins=bins, right=False)
        binned = df_full.groupby("bin").agg(
            time_to_recover=("time_to_recover", "mean"),
            prob=("prob", "sum"),
            smoothed=("smoothed", "mean"),
        ).reset_index(drop=True)
        plot_df = binned
    else:
        plot_df = df_full

    # Calculate expected time, std, median, p90 from raw `result` (more accurate than binned)
    # Ensure probabilities sum to 1 (or use normalization if not)
    _total_prob = sum(distribution.values())
    if _total_prob <= 0:
        print("Total probability is zero or negative — nothing to summarize/plot.")
        return
    else:
        # normalize if necessary
        items = sorted(distribution.items())
        times = np.array([t for t, p in items], dtype=float)
        probs = np.array([p for t, p in items], dtype=float)
        if abs(_total_prob - 1.0) > 1e-8:
            probs = probs / _total_prob

        expected_time = float(np.sum(times * probs))
        var_time = float(np.sum(((times - expected_time) ** 2) * probs))
        std_time = math.sqrt(var_time)

        # median and percentile via cumulative sum
        cumsum = np.cumsum(probs)
        median_time = float(times[np.searchsorted(cumsum, 0.5)])
        p90_time = float(times[np.searchsorted(cumsum, 0.9)])

    # Print summary statistics
    print(f"Expected time to recover: {expected_time:.3f}")
    print(f"expected payload bits/packet: {math.log2(D)/expected_time:.3f}")
    print(f"Std dev: {std_time:.3f}")
    print(f"Median: {median_time:.3f}, 90th percentile: {p90_time:.3f}")

    # Determine x-axis tick spacing to keep labels readable (about 20 ticks max)
    # Guard against NaN in the plot_df time bounds
    pf_min = plot_df["time_to_recover"].min()
    pf_max = plot_df["time_to_recover"].max()
    if pd.isna(pf_min) or pd.isna(pf_max):
        print("Plot DataFrame has invalid time bounds — skipping ticks and plotting.")
        pf_min = 0
        pf_max = 0
    plot_range_len = int(pf_max - pf_min + 1)
    tick_step = max(1, int(plot_range_len / 20))
    # Use integer tickvals where possible
    tickvals = list(range(int(plot_df["time_to_recover"].min()), int(plot_df["time_to_recover"].max()) + 1, tick_step))

    # Build figure: bar + smoothed line overlay for readability
    fig = go.Figure()
    fig.add_trace(
        go.Bar(
            x=plot_df["time_to_recover"],
            y=plot_df["prob"],
            name="probability",
            marker_color="steelblue",
            opacity=0.6,
            hovertemplate="Time=%{x}<br>Probability=%{y:.6f}<extra></extra>",
        )
    )
    fig.add_trace(
        go.Scatter(
            x=plot_df["time_to_recover"],
            y=plot_df["smoothed"],
            mode="lines",
            name=f"smoothed (gaussian, sigma={sigma:.2f})",
            line=dict(color="firebrick", width=2),
            hovertemplate="Time=%{x}<br>Smoothed=%{y:.6f}<extra></extra>",
        )
    )

    # Add vertical lines/annotations for expected and median if finite
    ymax = max(float(plot_df["prob"].max()), float(plot_df["smoothed"].max()))
    if not math.isnan(expected_time):
        fig.add_shape(type="line", x0=expected_time, x1=expected_time, y0=0, y1=ymax * 1.05,
                    line=dict(color="green", width=2, dash="dash"), name="expected")
        fig.add_annotation(x=expected_time, y=ymax * 1.05, text=f"E={expected_time:.2f}", showarrow=True, arrowhead=2, ax=0, ay=-30)
    if not math.isnan(median_time):
        fig.add_shape(type="line", x0=median_time, x1=median_time, y0=0, y1=ymax * 1.05,
                    line=dict(color="orange", width=2, dash="dot"), name="median")
        fig.add_annotation(x=median_time, y=ymax * 1.05, text=f"median={median_time:.0f}", showarrow=True, arrowhead=2, ax=0, ay=-50)

    fig.update_layout(
        title="Time-to-Recover Distribution (smoothed)",
        xaxis_title="Time to recover (steps)",
        yaxis_title="Probability",
        template="plotly_white",
        bargap=0.1,
        legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1),
    )
    fig.update_xaxes(tickmode="array", tickvals=tickvals)

    # Export a lightweight HTML fragment when falling back; use full_html=False to avoid large wrapper
    try:
        fig.show()
    except Exception as e:
        msg = str(e)
        if "nbformat" in msg or "Mime type rendering requires nbformat" in msg:
            print("nbformat isn't available or is too old in this environment — falling back to compact HTML export for the figure.")
            html = pio.to_html(fig, include_plotlyjs='cdn', full_html=False)
            display(HTML(html))
        else:
            raise

# %%
def visual_test(
    producer_constructor: Callable[[int, int, int], Producer],
    recoverer_constructor: Callable[[int, int], Recoverer],
    N: int,
    D: int,
    passes: int = 100,
    sample_burst_size: Callable[[], int] = lambda: random.randint(1, 10),
    sample_data_size: Callable[[], int] = lambda: random.randint(3, 5),
    iters_bound: int = 300,
):
    visualize_distribution(
        D,
        test(
            producer_constructor,
            recoverer_constructor,
            N,
            D,
            passes,
            sample_burst_size,
            sample_data_size,
            iters_bound,
        )
    )

# %%
from impls.fountain import producer_constructor, recoverer_constructor

# TODO: check why isnt it working
visual_test(
    producer_constructor,
    recoverer_constructor,
    N=5,
    D=9999360,
    passes=100,
)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   4%|▍         | 4/100 [00:00<00:05, 17.50it/s]
# Failed to recover 835629 within iteration bound
# Failed to recover 8977644 within iteration bound
# Failed to recover 7933799 within iteration bound
# 100%|██████████| 100/100 [00:04<00:00, 20.33it/s]
# 99 failures.
# 1 MISMATCHES!!!
# Empty distribution — nothing to plot.

# %%
from impls.fullrank_matrix import producer_constructor, recoverer_constructor

visual_test(
    producer_constructor,
    recoverer_constructor,
    N=5,
    D=9999360,
    passes=10000,
)
# Out:
# 100%|██████████| 10000/10000 [00:13<00:00, 747.48it/s]
# 0 failures.
# Expected time to recover: 25.519
# expected payload bits/packet: 0.911
# Std dev: 9.844
# Median: 24.000, 90th percentile: 38.000
# nbformat isn't available or is too old in this environment — falling back to compact HTML export for the figure.
# <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="89d8afe7-8f0e-4784-95b1-02e2fed2db4a" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("89d8afe7-8f0e-4784-95b1-02e2fed2db4a")) {                    Plotly.newPlot(                        "89d8afe7-8f0e-4784-95b1-02e2fed2db4a",                        [{"hovertemplate":"Time=%{x}\u003cbr\u003eProbability=%{y:.6f}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"steelblue"},"name":"probability","opacity":0.6,"x":{"dtype":"i1","bdata":"CQoLDA0ODxAREhMUFRYXGBkaGxwdHh8gISIjJCUmJygpKissLS4vMDEyMzQ1Njc4OTo7PD0+P0BBQkNERUZHSElKS0xNTk9QUVJTVFVWV1hZWltcXV5fYGFiY2RlZmdoaWprbG1ubw=="},"y":{"dtype":"f8","bdata":"xY8xdy0hXz9GJXUCmgh7PxNhw9MrZYk\u002fSFD8GHPXkj\u002f6fmq8dJOYP0oMAiuHFpk\u002fP1dbsb\u002fsnj92cRsN4C2gP6RwPQrXo6A\u002fEoPAyqFFpj\u002fNO07RkVyuP1OWIY51cas\u002fE2HD0ytlqT8wKqkT0ESoP9UJaCJseKo\u002fKH6MuWsJqT+At0CC4seoP1HaG3xhMqU\u002fw\u002fUoXI\u002fCpT+cxCCwcmihP8xdS8gHPZs\u002fKVyPwvUonD8Rx7q4jQagP8Dsnjws1Jo\u002fK4cW2c73kz+4HoXrUbiOP\u002fyp8dJNYpA\u002fCRueXinLkD9n1edqK\u002faHP7WmeccpOoI\u002fukkMAiuHhj85tMh2vp+KP1XBqKROQIM\u002frthfdk8edj8tQxzr4jZ6PzvfT42XboI\u002f+n5qvHSTaD9IUPwYc9diP8e6uI0G8HY\u002f+n5qvHSTaD8JG55eKctwP6yt2F92T24\u002fE2HD0ytlaT+U9gZfmExlP5LLf0i\u002ffU0\u002f+n5qvHSTWD8VjErqBDRhP5T2Bl+YTFU\u002f\u002fKnx0k1iUD+U9gZfmExVPy1DHOviNko\u002fx7q4jQbwRj\u002fHuriNBvBGP8e6uI0G8EY\u002fYTJVMCqpMz8tQxzr4jYaPy1DHOviNjo\u002fx7q4jQbwRj9hMlUwKqkzP2EyVTAqqUM\u002fx7q4jQbwRj8tQxzr4jYaP\u002fyp8dJNYkA\u002fLUMc6+I2Kj8AAAAAAAAAAC1DHOviNho\u002fLUMc6+I2Gj8tQxzr4jYqPwAAAAAAAAAALUMc6+I2Gj8tQxzr4jYqPy1DHOviNio\u002fAAAAAAAAAAAtQxzr4jYaPy1DHOviNho\u002fAAAAAAAAAAAtQxzr4jYaPy1DHOviNho\u002fLUMc6+I2Gj8AAAAAAAAAAC1DHOviNio\u002fAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAALUMc6+I2Gj8AAAAAAAAAAC1DHOviNho\u002fAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAtQxzr4jYaPwAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAALUMc6+I2Gj8="},"type":"bar"},{"hovertemplate":"Time=%{x}\u003cbr\u003eSmoothed=%{y:.6f}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"firebrick","width":2},"mode":"lines","name":"smoothed (gaussian, sigma=1.03)","x":{"dtype":"i1","bdata":"CQoLDA0ODxAREhMUFRYXGBkaGxwdHh8gISIjJCUmJygpKissLS4vMDEyMzQ1Njc4OTo7PD0+P0BBQkNERUZHSElKS0xNTk9QUVJTVFVWV1hZWltcXV5fYGFiY2RlZmdoaWprbG1ubw=="},"y":{"dtype":"f8","bdata":"u12t31HsaT8YES8Kap99P9YwMxWUn4k\u002ffOG+z1Rfkj+mf3RKhO6WP+0V2YSnaZo\u002fsdqtsiuinT9z7Q\u002fItlGgPyO0irN7qqI\u002fuQyJsqnKpj95vfYup3yqPy0V6fvhGKs\u002fQ\u002f2WpD30qT+EqgVbqVepP\u002fUbn3qSZ6k\u002fSQrcoMgIqT+vuzByh9qnP6iHaNulMKY\u002frz0GV9g+pD9dpgszzpqhP7IfdGz0nZ4\u002ft8A7vDw7nT87wylnh8acP5kxThXCx5k\u002f8lqdSm8KlT+rB2qvJ46RPzR3q6h0NJA\u002f72OatGz2jT9ikQYPkGOJP9iEqJ1zI4Y\u002fvUjf6yVehj\u002fGteH\u002fulmGP8SPn9TH34I\u002f2myTHt3XfT\u002fDqo5Xm8J7P0WPNSpNy3k\u002fg7VhyfcJcz8ucdbYI5puP\u002fEFxraYI3A\u002fUeTi3Fzpbz\u002fFdy4Kl7RuPxrNvJl1AW0\u002fE2ErmP\u002fvaD9TgNmPnPdiP8uBAC67bVs\u002fRQwwUzWLWT+kfXYjXJ1aP3kscvkfZFc\u002f4VIrfrClUz98jBe4rpFRPyPOZdt9pk0\u002f+d9CykreSD8f2Ij\u002f\u002f1tGPwpmg8APk0I\u002fQIWGK\u002fMMOT87f1fpomUzP+WE0H1FoDk\u002f24X0EGXvPz+oZA4p00RAP3iMRor9P0E\u002ffTbYL10kQD\u002fn\u002fcx8\u002fMA4PwbG9HsJaDQ\u002fEkYukYQiLD8Fp1do\u002fbUcP7UnPgtwZRc\u002fHQmQdvGdHT9dZhrwHwgeP7eR2PbIFRg\u002fxebgS\u002fQmHT\u002fpSuMzJ+MjP6OytnjsHCI\u002ffLwNIfvKFz9FRMnpKQUUPyw99MNtehI\u002fuZcAHj7SDz8Mb\u002f4TXLoTP5mfV4rRRhc\u002fiAvuTrEfFT9IrmPVgrUUPyCLJ\u002fPcABY\u002fjFB3XBvyCT83VfzF0YDyPnelorNSHfs+nScXLjJmBz8WpuGwf1wJP50nFy4yZgc\u002fjFB3XBvy+T6fcVBdwqvYPrVOtXJ1s6I+AAAAAAAAAAC1TrVydbOiPp9xUF3Cq9g+FqbhsH9c+T5pGW3iuVAEPxam4bB\u002fXPk+n3FQXcKr2D61TrVydbOiPgAAAAAAAAAAtU61cnWz ...
